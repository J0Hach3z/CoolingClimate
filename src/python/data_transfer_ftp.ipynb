# %% [markdown]
# # Install necessary packages

# %%
pip install netCDF4 pandas numpy matplotlib cartopy xarray fsspec aiohttp scipy h5netcdf sqlalchemy configparser psycopg2
# Out:
# Requirement already satisfied: netCDF4 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: pandas in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: numpy in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (2.3.2)
# Requirement already satisfied: matplotlib in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (3.10.5)
# Requirement already satisfied: cartopy in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (0.25.0)
# Requirement already satisfied: xarray in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (2025.7.1)
# Collecting fsspec
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.12.15-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting scipy
#   Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: h5netcdf in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (1.6.4)
# Requirement already satisfied: sqlalchemy in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (2.0.42)
# Requirement already satisfied: configparser in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (7.2.0)
# Requirement already satisfied: psycopg2 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (2.9.10)
# Requirement already satisfied: cftime in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from netCDF4) (1.6.4.post1)
# Requirement already satisfied: certifi in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from netCDF4) (2025.7.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: shapely>=2.0 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from cartopy) (2.1.1)
# Requirement already satisfied: pyshp>=2.3 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.3.1 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from cartopy) (3.7.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from aiohttp) (24.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp)
#   Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp)
#   Downloading multidict-6.6.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp)
#   Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp)
#   Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Requirement already satisfied: idna>=2.0 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.7)
# Requirement already satisfied: h5py in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from h5netcdf) (3.14.0)
# Requirement already satisfied: greenlet>=1 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from sqlalchemy) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: six>=1.5 in /home/vub-flow/anaconda3/envs/SES_climate_cooling/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading aiohttp-3.12.15-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 116.2 MB/s eta 0:00:00
# Downloading multidict-6.6.4-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (246 kB)
# Downloading yarl-1.20.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (348 kB)
# Downloading scipy-1.16.2-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 70.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.7.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
# Downloading propcache-0.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Installing collected packages: scipy, propcache, multidict, fsspec, frozenlist, aiohappyeyeballs, yarl, aiosignal, aiohttp
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9/9 [aiohttp]5;237m━━━━ 8/9 [aiohttp]
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.15 aiosignal-1.4.0 frozenlist-1.7.0 fsspec-2025.9.0 multidict-6.6.4 propcache-0.3.2 scipy-1.16.2 yarl-1.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from configparser import ConfigParser
from datetime import datetime, timedelta
import fsspec
from ftplib import FTP
import matplotlib as mpl
import matplotlib.animation as animation
import matplotlib.pyplot    as plt
import netCDF4
import numpy as np
import os
import pandas as pd
from sqlalchemy import create_engine, Table, MetaData, insert
import tempfile
import xarray as xr

# %% [markdown]
# # List files

# %%
def list_ftp_dir(host: str, path: str):
    ftp = FTP(host)
    ftp.login()  # assumes anonymous or you might need credentials
    ftp.cwd(path)
    files = ftp.nlst()  # list names in current directory
    ftp.quit()
    return files

if __name__ == "__main__":
    host = "ftp.climato.be"
    path = "fettweis/MARv3.14/Belgium/full/"
    files = list_ftp_dir(host, path)
    files.remove("download.bash")
    files.remove("tas.bash")
    files.remove("ERA5")
    models = files
    print(models)
    for model in models:
        path2 = f"fettweis/MARv3.14/Belgium/full/{model}"
        print(model)
        files = list_ftp_dir(host, path2)
        ssps = ['ssp126', 'ssp245', 'ssp370', 'ssp585']
        for ssp in ssps:
            path3 = f"fettweis/MARv3.14/Belgium/full/{model}/{ssp}"
            print(f" {ssp}")
            maps = list_ftp_dir(host, path+model+'/'+ssp)
            for Map in maps[0:5]:
                path4 = f"fettweis/MARv3.14/Belgium/full/{model}/{ssp}/{Map}"
                print(f"  {path4}")
            print(f"  ...")
# Out:
# ['CMCC-CM2-SR5', 'EC-Earth3-Veg', 'IPSL-CM6A-LR', 'MIROC6', 'MPI-ESM1-2-HR', 'NorESM2-MM']
# CMCC-CM2-SR5
#  ssp126
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2015.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2016.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2017.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2018.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2019.nc
#   ...
#  ssp245
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp245/MARv3.14-CMCC-CM2-SR5-ssp245-2015.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp245/MARv3.14-CMCC-CM2-SR5-ssp245-2016.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp245/MARv3.14-CMCC-CM2-SR5-ssp245-2017.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp245/MARv3.14-CMCC-CM2-SR5-ssp245-2018.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp245/MARv3.14-CMCC-CM2-SR5-ssp245-2019.nc
#   ...
#  ssp370
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp370/MARv3.14-CMCC-CM2-SR5-ssp370-2015.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp370/MARv3.14-CMCC-CM2-SR5-ssp370-2016.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp370/MARv3.14-CMCC-CM2-SR5-ssp370-2017.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp370/MARv3.14-CMCC-CM2-SR5-ssp370-2018.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp370/MARv3.14-CMCC-CM2-SR5-ssp370-2019.nc
#   ...
#  ssp585
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp585/MARv3.14-CMCC-CM2-SR5-ssp585-2015.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp585/MARv3.14-CMCC-CM2-SR5-ssp585-2016.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp585/MARv3.14-CMCC-CM2-SR5-ssp585-2017.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp585/MARv3.14-CMCC-CM2-SR5-ssp585-2018.nc
#   fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp585/MARv3.14-CMCC-CM2-SR5-ssp585-2019.nc
#   ...
# EC-Earth3-Veg
#  ssp126
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp126/MARv3.14-EC-Earth3-Veg-ssp126-2015.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp126/MARv3.14-EC-Earth3-Veg-ssp126-2016.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp126/MARv3.14-EC-Earth3-Veg-ssp126-2017.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp126/MARv3.14-EC-Earth3-Veg-ssp126-2018.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp126/MARv3.14-EC-Earth3-Veg-ssp126-2019.nc
#   ...
#  ssp245
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp245/MARv3.14-EC-Earth3-Veg-ssp245-2015.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp245/MARv3.14-EC-Earth3-Veg-ssp245-2016.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp245/MARv3.14-EC-Earth3-Veg-ssp245-2017.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp245/MARv3.14-EC-Earth3-Veg-ssp245-2018.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp245/MARv3.14-EC-Earth3-Veg-ssp245-2019.nc
#   ...
#  ssp370
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp370/MARv3.14-EC-Earth3-Veg-ssp370-2015.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp370/MARv3.14-EC-Earth3-Veg-ssp370-2016.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp370/MARv3.14-EC-Earth3-Veg-ssp370-2017.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp370/MARv3.14-EC-Earth3-Veg-ssp370-2018.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp370/MARv3.14-EC-Earth3-Veg-ssp370-2019.nc
#   ...
#  ssp585
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp585/MARv3.14-EC-Earth3-Veg-ssp585-2015.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp585/MARv3.14-EC-Earth3-Veg-ssp585-2016.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp585/MARv3.14-EC-Earth3-Veg-ssp585-2017.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp585/MARv3.14-EC-Earth3-Veg-ssp585-2018.nc
#   fettweis/MARv3.14/Belgium/full/EC-Earth3-Veg/ssp585/MARv3.14-EC-Earth3-Veg-ssp585-2019.nc
#   ...
# IPSL-CM6A-LR
#  ssp126
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp126/MARv3.14-IPSL-CM6A-LR-ssp126-2015.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp126/MARv3.14-IPSL-CM6A-LR-ssp126-2016.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp126/MARv3.14-IPSL-CM6A-LR-ssp126-2017.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp126/MARv3.14-IPSL-CM6A-LR-ssp126-2018.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp126/MARv3.14-IPSL-CM6A-LR-ssp126-2019.nc
#   ...
#  ssp245
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp245/MARv3.14-IPSL-CM6A-LR-ssp245-2015.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp245/MARv3.14-IPSL-CM6A-LR-ssp245-2016.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp245/MARv3.14-IPSL-CM6A-LR-ssp245-2017.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp245/MARv3.14-IPSL-CM6A-LR-ssp245-2018.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp245/MARv3.14-IPSL-CM6A-LR-ssp245-2019.nc
#   ...
#  ssp370
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp370/MARv3.14-IPSL-CM6A-LR-ssp370-2015.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp370/MARv3.14-IPSL-CM6A-LR-ssp370-2016.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp370/MARv3.14-IPSL-CM6A-LR-ssp370-2017.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp370/MARv3.14-IPSL-CM6A-LR-ssp370-2018.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp370/MARv3.14-IPSL-CM6A-LR-ssp370-2019.nc
#   ...
#  ssp585
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp585/MARv3.14-IPSL-CM6A-LR-ssp585-2015.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp585/MARv3.14-IPSL-CM6A-LR-ssp585-2016.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp585/MARv3.14-IPSL-CM6A-LR-ssp585-2017.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp585/MARv3.14-IPSL-CM6A-LR-ssp585-2018.nc
#   fettweis/MARv3.14/Belgium/full/IPSL-CM6A-LR/ssp585/MARv3.14-IPSL-CM6A-LR-ssp585-2019.nc
#   ...
# MIROC6
#  ssp126
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp126/MARv3.14-MIROC6-ssp126-2015.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp126/MARv3.14-MIROC6-ssp126-2016.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp126/MARv3.14-MIROC6-ssp126-2017.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp126/MARv3.14-MIROC6-ssp126-2018.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp126/MARv3.14-MIROC6-ssp126-2019.nc
#   ...
#  ssp245
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp245/MARv3.14-MIROC6-ssp245-2015.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp245/MARv3.14-MIROC6-ssp245-2016.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp245/MARv3.14-MIROC6-ssp245-2017.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp245/MARv3.14-MIROC6-ssp245-2018.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp245/MARv3.14-MIROC6-ssp245-2019.nc
#   ...
#  ssp370
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp370/MARv3.14-MIROC6-ssp370-2015.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp370/MARv3.14-MIROC6-ssp370-2016.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp370/MARv3.14-MIROC6-ssp370-2017.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp370/MARv3.14-MIROC6-ssp370-2018.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp370/MARv3.14-MIROC6-ssp370-2019.nc
#   ...
#  ssp585
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp585/MARv3.14-MIROC6-ssp585-2015.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp585/MARv3.14-MIROC6-ssp585-2016.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp585/MARv3.14-MIROC6-ssp585-2017.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp585/MARv3.14-MIROC6-ssp585-2018.nc
#   fettweis/MARv3.14/Belgium/full/MIROC6/ssp585/MARv3.14-MIROC6-ssp585-2019.nc
#   ...
# MPI-ESM1-2-HR
#  ssp126
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp126/MARv3.14-MPI-ESM1-2-HR-ssp126-2015.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp126/MARv3.14-MPI-ESM1-2-HR-ssp126-2016.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp126/MARv3.14-MPI-ESM1-2-HR-ssp126-2017.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp126/MARv3.14-MPI-ESM1-2-HR-ssp126-2018.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp126/MARv3.14-MPI-ESM1-2-HR-ssp126-2019.nc
#   ...
#  ssp245
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp245/MARv3.14-MPI-ESM1-2-HR-ssp245-2015.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp245/MARv3.14-MPI-ESM1-2-HR-ssp245-2016.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp245/MARv3.14-MPI-ESM1-2-HR-ssp245-2017.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp245/MARv3.14-MPI-ESM1-2-HR-ssp245-2018.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp245/MARv3.14-MPI-ESM1-2-HR-ssp245-2019.nc
#   ...
#  ssp370
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp370/MARv3.14-MPI-ESM1-2-HR-ssp370-2015.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp370/MARv3.14-MPI-ESM1-2-HR-ssp370-2016.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp370/MARv3.14-MPI-ESM1-2-HR-ssp370-2017.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp370/MARv3.14-MPI-ESM1-2-HR-ssp370-2018.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp370/MARv3.14-MPI-ESM1-2-HR-ssp370-2019.nc
#   ...
#  ssp585
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp585/MARv3.14-MPI-ESM1-2-HR-ssp585-2015.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp585/MARv3.14-MPI-ESM1-2-HR-ssp585-2016.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp585/MARv3.14-MPI-ESM1-2-HR-ssp585-2017.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp585/MARv3.14-MPI-ESM1-2-HR-ssp585-2018.nc
#   fettweis/MARv3.14/Belgium/full/MPI-ESM1-2-HR/ssp585/MARv3.14-MPI-ESM1-2-HR-ssp585-2019.nc
#   ...
# NorESM2-MM
#  ssp126
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp126/MARv3.14-NorESM2-MM-ssp126-2015.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp126/MARv3.14-NorESM2-MM-ssp126-2016.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp126/MARv3.14-NorESM2-MM-ssp126-2017.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp126/MARv3.14-NorESM2-MM-ssp126-2018.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp126/MARv3.14-NorESM2-MM-ssp126-2019.nc
#   ...
#  ssp245
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp245/MARv3.14-NorESM2-MM-ssp245-2015.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp245/MARv3.14-NorESM2-MM-ssp245-2016.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp245/MARv3.14-NorESM2-MM-ssp245-2017.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp245/MARv3.14-NorESM2-MM-ssp245-2018.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp245/MARv3.14-NorESM2-MM-ssp245-2019.nc
#   ...
#  ssp370
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp370/MARv3.14-NorESM2-MM-ssp370-2015.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp370/MARv3.14-NorESM2-MM-ssp370-2016.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp370/MARv3.14-NorESM2-MM-ssp370-2017.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp370/MARv3.14-NorESM2-MM-ssp370-2018.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp370/MARv3.14-NorESM2-MM-ssp370-2019.nc
#   ...
#  ssp585
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp585/MARv3.14-NorESM2-MM-ssp585-2015.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp585/MARv3.14-NorESM2-MM-ssp585-2016.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp585/MARv3.14-NorESM2-MM-ssp585-2017.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp585/MARv3.14-NorESM2-MM-ssp585-2018.nc
#   fettweis/MARv3.14/Belgium/full/NorESM2-MM/ssp585/MARv3.14-NorESM2-MM-ssp585-2019.nc
#   ...

# %% [markdown]
# # Code for animation (unecessary)

# %%
fp = "/Users/jonathanhachez/Downloads/MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc"

nc = netCDF4.Dataset(fp)

print(nc.variables.keys())  # Lists available variables
print(nc.dimensions.keys())  # Lists dimensions
print(nc)  # Prints dataset summary

plt.figure(figsize=(10, 8))
def plot_heat_map(k):
    # k = k + 8760/3*20
    plt.clf()# Assuming nc["tas"][k,:,:] is your 2D array
    # Set up the map projection
    
    ax = plt.axes(projection=ccrs.PlateCarree())
    
    
    t2m = nc["T2m"][k, :, :]
    lon = nc["LON"][:]  # Make sure this is the correct variable name
    lat = nc["LAT"][:]  # Make sure this is the correct variable name
    
    im = plt.pcolormesh(lon, lat, t2m, 
                     cmap="inferno",
                     vmin=-10,
                     vmax=40,
                     shading='auto')


    plt.plot(4.3572,50.8477, marker = 'x',color = 'black')
    plt.colorbar()
    
    # Add geographic features directly to current axes
    ax.add_feature(cfeature.COASTLINE, linewidth=1)
    ax.add_feature(cfeature.BORDERS, linestyle=':', linewidth=0.8)
    
    # Define the start date
    start_date = datetime(2035, 1, 1, 0, 0, 0)  # 01-01-2015 00:00:00
    
    new_date = start_date + timedelta(hours=1 * k)
    
    # Format the date for matplotlib (e.g., "2015-01-01 15:00:00")
    date_str = new_date.strftime("%Y-%m-%d %H:%M")
    
    plt.title(f"Temperature Belgium {date_str}")
    return plt

# cbar = fig.colorbar(im, ax=ax)
anim = animation.FuncAnimation(plt.figure(), plot_heat_map, interval = 10, frames = 3*24, repeat = False)
writer = animation.PillowWriter(fps = 14, metadata=dict(artist='Me'),bitrate=1800)
anim.save('unknown.gif', writer = writer)
# Out:
# dict_keys(['CC', 'DD', 'DIST', 'EP', 'ET', 'HH', 'LAT', 'LHF', 'LON', 'LWD', 'MIN', 'MM', 'Q2m', 'RF', 'RH2m', 'RO1', 'RO2', 'RO3', 'RO4', 'RO5', 'RO6', 'RU', 'SF', 'SH', 'SHF', 'SH_MAR', 'SL', 'SLP', 'SMB', 'SN', 'SP', 'SQC', 'SQM', 'ST', 'SWD', 'SWDD', 'T2m', 'U10m', 'U2m', 'YYYY', 'ZN', 'time', 'x', 'y'])
# dict_keys(['time', 'y', 'x'])
# <class 'netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC data model, file format HDF5):
#     title: Hourly MARv3.14 outputs in 2067 interpolated on the 5x5km^2 grid from IRM using CMCC-CM2-SR5-ssp245
#     institution: University of Liège (Belgium)
#     netcdf: 4.4.1 of Mar 21 2022 20:38:41 $
#     institute: University of Liege (Belgium)
#     NCO: netCDF Operators version 5.1.7 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco, DOI = 10.1016/j.envsoft.2008.03.004)
#     contact: xavier.fettweis@uliege.be
#     history: Mon Dec 25 12:45:17 2023: ncks -4 --cnk_dmn y,55 --cnk_dmn x,66 --cnk_dmn time,1 -L 4 out/MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc out/MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc4
# Mon Dec 25 12:45:17 2023: ncatted -a model,global,o,c,regional climate model MARv3.14.0 out/MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc
# Mon Dec 25 12:45:17 2023: ncatted -a contact,global,o,c,xavier.fettweis@uliege.be out/MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc
# Mon Dec 25 12:45:17 2023: ncatted -a institute,global,o,c,University of Liege (Belgium) out/MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc
# libUN (2013.05.22) - Mon Dec 25 12:28:14 2023
#     model: regional climate model MARv3.14.0
#     dimensions(sizes): time(8760), y(55), x(66)
#     variables(dimensions): float32 CC(time, y, x), float32 DD(time), float32 DIST(y, x), float32 EP(time, y, x), float32 ET(time, y, x), float32 HH(time), float32 LAT(y, x), float32 LHF(time, y, x), float32 LON(y, x), float32 LWD(time, y, x), float32 MIN(time), float32 MM(time), float32 Q2m(time, y, x), float32 RF(time, y, x), float32 RH2m(time, y, x), float32 RO1(time, y, x), float32 RO2(time, y, x), float32 RO3(time, y, x), float32 RO4(time, y, x), float32 RO5(time, y, x), float32 RO6(time, y, x), float32 RU(time, y, x), float32 SF(time, y, x), float32 SH(y, x), float32 SHF(time, y, x), float32 SH_MAR(y, x), float32 SL(time, y, x), float32 SLP(time, y, x), float32 SMB(time, y, x), float32 SN(time, y, x), float32 SP(time, y, x), float32 SQC(time, y, x), float32 SQM(y, x), float32 ST(time, y, x), float32 SWD(time, y, x), float32 SWDD(time, y, x), float32 T2m(time, y, x), float32 U10m(time, y, x), float32 U2m(time, y, x), float32 YYYY(time), float32 ZN(time, y, x), float32 time(time), float32 x(x), float32 y(y)
#     groups:

# %%
def process_nc_remote(file_url: str, varname: str):
    # Download the file to a temporary location
    with tempfile.NamedTemporaryFile(suffix='.nc', delete=False) as tmp_file:
        tmp_path = tmp_file.name
    
    try:
        # Download using fsspec
        with fsspec.open(file_url, 'rb') as remote_file:
            with open(tmp_path, 'wb') as local_file:
                local_file.write(remote_file.read())
        
        # Process the local file
        # Process the local file
        ds = xr.open_dataset(tmp_path, engine='netcdf4')
        da = ds[varname]
        mean_da = da.mean(dim='time', skipna=True)
        result = mean_da.compute().values
        ds.close()
        
        return 0
    finally:
        # Clean up
        if os.path.exists(tmp_path):
            os.unlink(tmp_path)

if __name__ == "__main__":
    host = "ftp.climato.be"
    path = "fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp245"
    fname = "MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc"
    file_url = f"ftp://{host}/{path}/{fname}"
    varname = "T2m"
    
    m = process_nc_remote(file_url, varname)
    print("Mean of", varname, ":", m)
# Out:
# Mean of T2m : 0
# /Users/jonathanhachez/opt/anaconda3/envs/HVAC_climate/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
tmp_path = "/Users/jonathanhachez/Downloads/MARv3.14-CMCC-CM2-SR5-ssp245-2067.nc"
ds = xr.open_dataset(tmp_path, engine='netcdf4')
print(ds.variables)
# Extract lon/lat arrays (2D)
lons = ds["LON"].values
lats = ds["LAT"].values

# Target location
target_lon = 5.0
target_lat = 50.5

# Compute distance to every grid cell
dist = np.sqrt((lons - target_lon)**2 + (lats - target_lat)**2)

# Find nearest indices
j, i = np.unravel_index(dist.argmin(), dist.shape)
print(f"Nearest grid point: lon={lons[j,i]}, lat={lats[j,i]}")

# Extract time series of temperature at that grid point
ts = ds["CC"].isel(y=j, x=i)   # adjust dim names if different
df = ts.to_dataframe(name="value").reset_index()[["time","value"]]
df["variable"] = ds["CC"].long_name
df["ssp"] = "ssp"
df["GCM"] = "model"
df["RCM"] = "MAR"

# Reorder columns
df = df[["time","variable","ssp","GCM","value"]]

print(df.head())

# %% [markdown]
# # DB configuration

# %%
def config(filename='db_access.ini', section='postgresql'):
    # create a parser
    parser = ConfigParser()
    # read config file
    parser.read(filename)

    # get section and update dictionary with connection string key:value pairs
    db = {}
    if section in parser:
        for key in parser[section]:
            db[key] = parser[section][key]
    else:
        raise Exception(
            'Section {0} not found in the {1} file'.format(section, filename))
    return db

# SQLAlchemy connection (for cleaner code)
def connect_SQL_alchemy():
    params = config()
    db_url = f"postgresql+psycopg2://{params['user']}:{params['password']}@{params['host']}:{params['port']}/{params['database']}"
    return create_engine(db_url)

def read_table(table_name = "belgium_res"):
    engine = connect_SQL_alchemy()
    metadata = MetaData()
    metadata.reflect(bind=engine, only = [table_name])
    table = metadata.tables.get(table_name)
    
    if table is None:
        raise ValueError(f"Table '{table_name}' not found in the database!")
    
    # 3. Fetch all data into a Pandas DataFrame
    query = table.select()  # SELECT * FROM table_name
    df = pd.read_sql(query, engine)
    return df

print(read_table(table_name = "belgium_res"))
# Out:
#           longitude  latitude                time                variable  \
# 0          4.375523  50.86203 2015-01-01 00:30:00             Cloud Cover
# 1          4.375523  50.86203 2015-01-01 01:30:00             Cloud Cover
# 2          4.375523  50.86203 2015-01-01 02:30:00             Cloud Cover
# 3          4.375523  50.86203 2015-01-01 03:30:00             Cloud Cover
# 4          4.375523  50.86203 2015-01-01 04:30:00             Cloud Cover
# ...             ...       ...                 ...                     ...
# 16305115   4.375523  50.86203 2076-12-31 19:30:00  Snow Pack Height Total
# 16305116   4.375523  50.86203 2076-12-31 20:30:00  Snow Pack Height Total
# 16305117   4.375523  50.86203 2076-12-31 21:30:00  Snow Pack Height Total
# 16305118   4.375523  50.86203 2076-12-31 22:30:00  Snow Pack Height Total
# 16305119   4.375523  50.86203 2076-12-31 23:30:00  Snow Pack Height Total
#
#                    gcm       rcm     ssp     value
# 0         CMCC-CM2-SR5  MARv3.14  ssp126  0.996893
# 1         CMCC-CM2-SR5  MARv3.14  ssp126  1.000000
# 2         CMCC-CM2-SR5  MARv3.14  ssp126  1.000000
# 3         CMCC-CM2-SR5  MARv3.14  ssp126  1.000000
# 4         CMCC-CM2-SR5  MARv3.14  ssp126  0.998081
# ...                ...       ...     ...       ...
# 16305115  CMCC-CM2-SR5  MARv3.14  ssp126  0.000000
# 16305116  CMCC-CM2-SR5  MARv3.14  ssp126  0.000000
# 16305117  CMCC-CM2-SR5  MARv3.14  ssp126  0.000000
# 16305118  CMCC-CM2-SR5  MARv3.14  ssp126  0.000000
# 16305119  CMCC-CM2-SR5  MARv3.14  ssp126  0.000000
#
# [16305120 rows x 8 columns]

# %%
        
# Function to check if a variable is defined on the spatial grid
def is_spatial_variable(var):
    """Check if variable has spatial dimensions (y and x)"""
    dims = var.dims
    # Check if it has both spatial dimensions (adjust names if different)
    has_spatial_dims = ('y' in dims and 'x' in dims) or ('lat' in dims and 'lon' in dims)
    
    # Also check if it's not a coordinate variable
    is_coord_var = var.name in ds.coords
    
    # Check if it has time dimension (optional, depending on your needs)
    has_time_dim = 'time' in dims
    
    return has_spatial_dims and not is_coord_var

# Alternative: more specific check for your use case
def is_valid_variable_for_extraction(var, ds):
    """Check if variable is suitable for spatial extraction"""
    dims = var.dims

    exclude_list = ['DIST','LAT','LON','SH','SH_MAR','SQM']
    # Skip coordinate variables
    if var.name in ds.coords or var.name in exclude_list:
        return False
    
    # Skip variables that don't have both spatial dimensions
    spatial_dims_present = ('y' in dims and 'x' in dims)
    if not spatial_dims_present:
        return False
    
    # Optional: also check if it has time dimension if you want time series
    # has_time_dim = 'time' in dims
    # return spatial_dims_present and has_time_dim
    
    return spatial_dims_present

def extract_variables(tmp_path, rcm, gcm, ssp, target_lon = 4.3572, target_lat = 50.8477):
    ds = xr.open_dataset(tmp_path, engine='netcdf4')
    
    # Extract lon/lat arrays (2D)
    lons = ds["LON"].values
    lats = ds["LAT"].values
    
    # Target location
    
    # Compute distance to every grid cell
    dist = np.sqrt((lons - target_lon)**2 + (lats - target_lat)**2)
    
    # Find nearest indices
    j, i = np.unravel_index(dist.argmin(), dist.shape)

    # Create a list to store all dataframes
    all_dfs = []
    
    # Process only valid spatial variables
    for varname in ds.data_vars:
        var = ds[varname]
        
        if is_valid_variable_for_extraction(var, ds):
            # Extract time series at the nearest grid point
            try:
                ts = ds[varname].isel(y=j, x=i)
                
                # Convert to dataframe
                df = ts.to_dataframe(name="value").reset_index()[["time", "value"]]
                df["variable"] = ds[varname].long_name
                df["ssp"] = ssp
                df["gcm"] = gcm
                df["rcm"] = rcm
                df["longitude"] = lons[j, i]
                df["latitude"] = lats[j, i]
                
                # Reorder columns
                df = df[["time", "variable", "ssp", "gcm", "rcm", "longitude", "latitude", "value"]]
                
                all_dfs.append(df)
                
            except Exception as e:
                print(f"Error processing {varname}: {e}")
        else:
            pass
            # print(f"Skipping {varname} (not a spatial variable)")
    
    # Combine all dataframes into one
    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        engine = connect_SQL_alchemy()
        # To this:
        with engine.connect() as conn:  # Use connect() method
            combined_df.to_sql('belgium_res', con=conn, if_exists='append', index=False)  # Note: parameter name is 'con', not 'connection'
        # Save to CSV if desired
        # with connect_SQL_alchemy() as conn:
        #     combined_df.to_sql('belgium_res', connection = conn)
    else:
        print("No spatial variables found to extract")
    
    # Close the dataset
    ds.close()

# %%
def process_nc_remote(file_url: str, rcm, gcm, ssp, target_lon = 4.3572, target_lat = 50.8477):
    with tempfile.NamedTemporaryFile(suffix='.nc', delete=False) as tmp_file:
        tmp_path = tmp_file.name

    
    # Configure FTP with longer timeout
    ftp_options = {
        'timeout': 60
    }
    
    try:
        print(f"\rProgress: Copying file", end="", flush=True)
        with fsspec.open(file_url, 'rb', **ftp_options) as remote_file:
            with open(tmp_path, 'wb') as local_file:
                local_file.write(remote_file.read())
        print(f"\rProgress: Extracting Variables", end="", flush=True)
        extract_variables(tmp_path = tmp_path, rcm = 'MARv3.14', gcm = model, ssp = ssp, target_lon = 4.3572, target_lat = 50.8477)
    finally:
        if os.path.exists(tmp_path):
            os.unlink(tmp_path)


def list_ftp_dir(host: str, path: str):
    ftp = FTP(host)
    ftp.login()  # assumes anonymous or you might need credentials
    ftp.cwd(path)
    files = ftp.nlst()  # list names in current directory
    ftp.quit()
    return files

if __name__ == "__main__":
    host = "ftp.climato.be"
    path = "fettweis/MARv3.14/Belgium/full/"
    files = list_ftp_dir(host, path)
    files.remove("download.bash")
    files.remove("tas.bash")
    files.remove("ERA5")
    models = files
    for model in ['IPSL-CM6A-LR']:
        path2 = f"fettweis/MARv3.14/Belgium/full/{model}"
        files = list_ftp_dir(host, path2)
        ssps = ['ssp126']
        for ssp in ssps:
            path3 = f"fettweis/MARv3.14/Belgium/full/{model}/{ssp}"
            maps = list_ftp_dir(host, path+model+'/'+ssp)
            for Map in ['MARv3.14-IPSL-CM6A-LR-ssp126-2016.nc']:
                year = int(Map[-7:-3])
                print(year)
                path4 = f"fettweis/MARv3.14/Belgium/full/{model}/{ssp}/{Map}"
                host = "ftp.climato.be"
                file_url = f"ftp://{host}/{path4}"
                process_nc_remote(file_url, rcm = 'MARv3.14', gcm = model, ssp = ssp, target_lon = 4.3572, target_lat = 50.8477)
                print(f"  processed {model}/{ssp}/{Map}")
# Out:
# 2016
# Progress: Extracting Variables  processed IPSL-CM6A-LR/ssp126/MARv3.14-IPSL-CM6A-LR-ssp126-2016.nc

# %%
import concurrent.futures
from functools import partial

def process_single_file(model, ssp, map_file, host):
    """Process a single file - this will be run in parallel"""
    path4 = f"fettweis/MARv3.14/Belgium/full/{model}/{ssp}/{map_file}"
    file_url = f"ftp://{host}/{path4}"
    print(path4, flush = True)
    try:
        process_nc_remote(file_url, rcm='MARv3.14', gcm=model, ssp=ssp, 
                         target_lon=4.3572, target_lat=50.8477)
        return f"✓ {model}/{ssp}/{map_file}"
    except Exception as e:
        return f"✗ {model}/{ssp}/{map_file} - Error: {str(e)}"

if __name__ == "__main__":
    host = "ftp.climato.be"
    path = "fettweis/MARv3.14/Belgium/full/"
    files = list_ftp_dir(host, path)
    files.remove("download.bash")
    files.remove("tas.bash")
    files.remove("ERA5")
    models = files
    
    # Collect all tasks
    all_tasks = []
    
    for model in models:
        path2 = f"fettweis/MARv3.14/Belgium/full/{model}"
        files = list_ftp_dir(host, path2)
        ssps = ['ssp126', 'ssp245', 'ssp370', 'ssp585']
        
        for ssp in ssps:
            path3 = f"fettweis/MARv3.14/Belgium/full/{model}/{ssp}"
            maps = list_ftp_dir(host, path+model+'/'+ssp)
            
            for map_file in maps:
                year = int(map_file[-7:-3])
                if model == 'CMCC-CM2-SR5' and (year <= 2077) and ssp == 'ssp126':
                    continue
                
                all_tasks.append((model, ssp, map_file))
    
    print(f"Total files to process: {len(all_tasks)}")
    print(all_tasks)

    # Process with ThreadPoolExecutor
    with concurrent.futures.ThreadPoolExecutor(max_workers=8) as executor:  # Adjust max_workers as needed
        # Create a partial function with fixed host parameter
        process_func = partial(process_single_file, host=host)
        
        # Submit all tasks
        future_to_task = {executor.submit(process_func, model, ssp, map_file): (model, ssp, map_file) 
                         for model, ssp, map_file in all_tasks}
        
        # Process results as they complete
        for future in concurrent.futures.as_completed(future_to_task):
            task = future_to_task[future]
            try:
                result = future.result()
                print(result)
            except Exception as e:
                print(f"✗ {task[0]}/{task[1]}/{task[2]} - Failed: {str(e)}")
# Out:
# Total files to process: 2000
# [('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2078.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2079.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2080.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2081.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2082.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2083.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2084.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2085.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2086.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2087.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2088.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2089.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2090.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2091.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2092.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2093.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2094.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2095.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2096.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2097.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2098.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2099.nc'), ('CMCC-CM2-SR5', 'ssp126', 'MARv3.14-CMCC-CM2-SR5-ssp126-2100.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2015.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2016.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2017.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2018.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2019.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2020.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2021.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2022.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2023.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2024.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2025.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2026.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2027.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2028.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2029.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2030.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2031.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2032.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2033.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2034.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2035.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2036.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2037.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2038.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2039.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2040.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2041.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2042.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2043.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2044.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2045.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2046.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2047.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2048.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp245-2049.nc'), ('CMCC-CM2-SR5', 'ssp245', 'MARv3.14-CMCC-CM2-SR5-ssp24 ...
# fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2078.nc
# fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2079.nc
# Progress: Copying filefettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2080.nc
# fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2081.nc
# Progress: Copying filefettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2082.nc
# fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2083.nc
# fettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2084.nc
# Progress: Copying filefettweis/MARv3.14/Belgium/full/CMCC-CM2-SR5/ssp126/MARv3.14-CMCC-CM2-SR5-ssp126-2085.nc
# Progress: Extracting Variables
